# %% [markdown]
# This notebook shows an example of a non-deterministic automaton that Seminator can turn into a semi-deterministic automaton that is smaller than the minimal equivalent deterministic automaton.
#
# Beside the Spot bindings (that start with `spot.`) we use two functions exported by Seminator: the `seminator()` function offers services similar to the command-line tool, and the `highlight_components()` can be used to color the first (purple) and second (green) components of a semi-deterministic automaton.

# %%
import spot
from spot.jupyter import display_inline
from spot.seminator import seminator, highlight_components
spot.setup(show_default='.v') # vertical display

# %%
nba = spot.translate('F(a & GFb) R c')
sdba = seminator(nba)
dba = spot.postprocess(nba, 'det')
# add some colors
spot.highlight_nondet_edges(nba, 5)
highlight_components(sdba)

# %%
display_inline(nba, sdba, dba)
# Out:
# <div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="125pt" height="292pt"
#  viewBox="0.00 0.00 125.00 292.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 288)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-288 121,-288 121,4 -4,4"/>
# <text text-anchor="start" x="37.5" y="-269.8" font-family="Lato" font-size="14.00">Inf(</text>
# <text text-anchor="start" x="59.5" y="-269.8" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# <text text-anchor="start" x="75.5" y="-269.8" font-family="Lato" font-size="14.00">)</text>
# <text text-anchor="start" x="35.5" y="-255.8" font-family="Lato" font-size="14.00">[Büchi]</text>
# <!-- I -->
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="#ffffaa" stroke="black" cx="27" cy="-192" rx="18" ry="18"/>
# <text text-anchor="middle" x="27" y="-188.3" font-family="Lato" font-size="14.00">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M27,-246.85C27,-245.21 27,-230.85 27,-217.37"/>
# <polygon fill="black" stroke="black" points="27,-210.06 30.15,-217.06 27,-213.56 27,-217.06 27,-217.06 27,-217.06 27,-213.56 23.85,-217.06 27,-210.06 27,-210.06"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="#e31a1c" stroke-width="2" d="M44.04,-198.38C53.86,-199.68 63,-197.55 63,-192 63,-187.83 57.86,-185.6 51.14,-185.29"/>
# <polygon fill="#e31a1c" stroke="#e31a1c" stroke-width="2" points="44.04,-185.62 50.88,-182.15 47.51,-184.96 51.01,-184.79 51.03,-185.29 51.05,-185.79 47.56,-185.96 51.18,-188.44 44.04,-185.62 44.04,-185.62"/>
# <text text-anchor="start" x="67.5" y="-195.8" font-family="Lato" font-size="14.00">c</text>
# <text text-anchor="start" x="63" y="-180.8" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="#ffffaa" stroke="black" cx="18" cy="-18" rx="18" ry="18"/>
# <text text-anchor="middle" x="18" y="-14.3" font-family="Lato" font-size="14.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="#e31a1c" stroke-width="2" d="M21.96,-174.42C18.09,-160.77 13.07,-140.83 11,-123 7.83,-95.66 10.89,-64.11 13.91,-42.99"/>
# <polygon fill="#e31a1c" stroke="#e31a1c" stroke-width="2" points="14.96,-35.98 17.04,-43.37 14.93,-39.51 14.41,-42.98 13.92,-42.9 13.43,-42.83 13.95,-39.37 10.8,-42.43 14.96,-35.98 14.96,-35.98"/>
# <text text-anchor="start" x="11" y="-101.3" font-family="Lato" font-size="14.00">a &amp; c</text>
# </g>
# <!-- 2 -->
# <g id="node4" class="node">
# <title>2</title>
# <ellipse fill="#ffffaa" stroke="black" cx="70" cy="-105" rx="18" ry="18"/>
# <text text-anchor="middle" x="70" y="-101.3" font-family="Lato" font-size="14.00">2</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g id="edge4" class="edge">
# <title>0&#45;&gt;2</title>
# <path fill="none" stroke="#e31a1c" stroke-width="2" d="M34.89,-175.41C41.62,-162.11 51.36,-142.84 58.88,-127.97"/>
# <polygon fill="#e31a1c" stroke="#e31a1c" stroke-width="2" points="62.16,-121.49 61.81,-129.16 61.03,-124.84 59.45,-127.96 59,-127.74 58.56,-127.51 60.14,-124.39 56.19,-126.32 62.16,-121.49 62.16,-121.49"/>
# <text text-anchor="start" x="51" y="-144.8" font-family="Lato" font-size="14.00">!a &amp; c</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M35.78,-21.78C45.31,-22.42 54,-21.16 54,-18 54,-15.68 49.32,-14.39 43.05,-14.12"/>
# <polygon fill="black" stroke="black" points="35.78,-14.22 42.73,-10.97 39.28,-14.17 42.78,-14.12 42.78,-14.12 42.78,-14.12 39.28,-14.17 42.83,-17.27 35.78,-14.22 35.78,-14.22"/>
# <text text-anchor="start" x="54" y="-14.3" font-family="Lato" font-size="14.00">!b</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge6" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M35.14,-24.14C52.58,-27.76 72,-25.71 72,-18 72,-11.31 57.4,-8.88 42.15,-10.71"/>
# <polygon fill="black" stroke="black" points="35.14,-11.86 41.54,-7.62 38.6,-11.29 42.05,-10.73 42.05,-10.73 42.05,-10.73 38.6,-11.29 42.56,-13.84 35.14,-11.86 35.14,-11.86"/>
# <text text-anchor="start" x="75.5" y="-21.8" font-family="Lato" font-size="14.00">b</text>
# <text text-anchor="start" x="72" y="-6.8" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# </g>
# <!-- 2&#45;&gt;1 -->
# <g id="edge7" class="edge">
# <title>2&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M60.94,-89.19C52.59,-75.54 40.11,-55.14 30.75,-39.84"/>
# <polygon fill="black" stroke="black" points="26.95,-33.64 33.29,-37.96 28.78,-36.62 30.61,-39.61 30.61,-39.61 30.61,-39.61 28.78,-36.62 27.92,-41.25 26.95,-33.64 26.95,-33.64"/>
# <text text-anchor="start" x="47" y="-57.8" font-family="Lato" font-size="14.00">a</text>
# </g>
# <!-- 2&#45;&gt;2 -->
# <g id="edge8" class="edge">
# <title>2&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M86.66,-112.38C96.62,-114.02 106,-111.56 106,-105 106,-100.08 100.73,-97.46 93.89,-97.16"/>
# <polygon fill="black" stroke="black" points="86.66,-97.62 93.45,-94.03 90.16,-97.39 93.65,-97.17 93.65,-97.17 93.65,-97.17 90.16,-97.39 93.85,-100.31 86.66,-97.62 86.66,-97.62"/>
# <text text-anchor="start" x="106" y="-101.3" font-family="Lato" font-size="14.00">!a</text>
# </g>
# </g>
# </svg>
# </div><div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="229pt" height="292pt"
#  viewBox="0.00 0.00 229.00 292.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 288)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-288 225,-288 225,4 -4,4"/>
# <text text-anchor="start" x="89.5" y="-269.8" font-family="Lato" font-size="14.00">Inf(</text>
# <text text-anchor="start" x="111.5" y="-269.8" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# <text text-anchor="start" x="127.5" y="-269.8" font-family="Lato" font-size="14.00">)</text>
# <text text-anchor="start" x="87.5" y="-255.8" font-family="Lato" font-size="14.00">[Büchi]</text>
# <!-- I -->
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="#ffffaa" stroke="#6a3d9a" stroke-width="2" cx="106" cy="-192" rx="18" ry="18"/>
# <text text-anchor="middle" x="106" y="-188.3" font-family="Lato" font-size="14.00">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M106,-246.85C106,-245.21 106,-230.85 106,-217.37"/>
# <polygon fill="black" stroke="black" points="106,-210.06 109.15,-217.06 106,-213.56 106,-217.06 106,-217.06 106,-217.06 106,-213.56 102.85,-217.06 106,-210.06 106,-210.06"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M123.04,-198.38C132.86,-199.68 142,-197.55 142,-192 142,-187.83 136.86,-185.6 130.14,-185.29"/>
# <polygon fill="black" stroke="black" points="123.04,-185.62 129.88,-182.15 126.53,-185.46 130.03,-185.29 130.03,-185.29 130.03,-185.29 126.53,-185.46 130.18,-188.44 123.04,-185.62 123.04,-185.62"/>
# <text text-anchor="start" x="142" y="-188.3" font-family="Lato" font-size="14.00">c</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="#ffffaa" stroke="#33a02c" stroke-width="2" cx="18" cy="-105" rx="18" ry="18"/>
# <text text-anchor="middle" x="18" y="-101.3" font-family="Lato" font-size="14.00">1</text>
# </g>
# <!-- 0&#45;&g

# %% [markdown]
# To show that the deterministic Büchi automaton on the right is minimal, we use Spot's `sat_minimize()` function, that uses a SAT-solver to find a smaller equivalent DBA if one exists.

# %%
assert dba.num_states() == spot.sat_minimize(dba).num_states()
